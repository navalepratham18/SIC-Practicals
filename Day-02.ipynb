# %% [markdown]
# # Date : 03/11/2025    -   Basis
# 1. Installation
# 2. Virtual Environment
# 3. Code Layout
#
#
# ### Datatypes in python
#
# 1. int : whole number (0 to infinity)
# 2. float : decimal point (0.0 to infinity)
# 3. string : Set of Characters   -> (can be defined by '', "", '''xyz''', etc.)
#
#
# ### Naming Conventions :
# 1. snake - eg : hello_world
# 2. camel - eg : helloWorld
# 3. pascal - eg: HelloWorld
#
# ### Errors :
# 1. Syntax Error
# 2. Runtime Error
#
# ### Error Handling :
# 1. try-except

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 1
type(a)    # getting the type of variable a
# Out:
# int

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print('''Hello
World''')

print('''\nHello\
World''')
# Out:
# Hello
# World
#
# HelloWorld

# %%
print("Hello", "World")
print(10,20)

print("hello", 10)
# Out:
# Hello World
# 10 20
# hello 10

# %%
print("Hello" + "World")
print(10+20)
# Out:
# HelloWorld
# 30

# %%
print("Hello " * 3)
print(3 * "Hello ")
print("Hello " * (2 + 1))
# Out:
# Hello Hello Hello
# Hello Hello Hello
# Hello Hello Hello

# %%
print("hello", end=" ")
print("world")

print("Hello", end=" , ")
print("World")
# Out:
# hello world
# Hello , World

# %%
print("Hello","World", sep="")
print("Hello","World", sep="+")
# Out:
# HelloWorld
# Hello+World

# %%
try : 
    a = int(input("Enter a number: "))
    print(a)
    print("Try block executed")
except : 
    print("Invalid Input")
# Out:
# Invalid Input

# %%
name = "prathamesh"
age = 20
print("Hello, My name is {} and I am {} years old.".format(name, age))
# Out:
# Hello, My name is prathamesh and I am 20 years old.
