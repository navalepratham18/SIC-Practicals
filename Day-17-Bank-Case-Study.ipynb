# %% [markdown]
# # Date : 01/01/25
#
# ## Case Study
#
# ### Creating bank
#
# 1. menu display
# 2. take choosees
# 3. enter account num
# 4. if a/c not found -> Create a/c
# 5. transaction
# 	- deposit
# 	- withdraw
# 	- check balance
# 	- exit

# %%
# bank a/c and operations

import sys


bank_db = {
    123456: {
        'name': 'Alice',
        'pin': 1234,
        'balance': 5000
    },
    987656: {
        'name': 'Bob',
        'pin': 9876,
        'balance': 10000
    }
}

def perform_transactions(user_acc):
    print("\nChoose an option :")
    choose2 = int(input("1. Deposit \n2. Withdraw \n3. Check Balace \n4. exit"))
    
    if choose2 == 1 : 
        deposit_amount = int(input("Enter the amount to DEPOSIT : "))
        bank_db[user_acc]['balance'] += deposit_amount
        
    elif choose2 == 2:
        withdraw_amount = int(input("Enter the amount to WITHDRAW :"))
        bank_db[user_acc]['balance'] -= withdraw_amount
        print("Withdrew Amount : ₹", withdraw_amount)
        print("Balance : ₹", bank_db[user_acc]['balance'])
        
    elif choose2 == 3 : 
        print("Balance Amount : ₹", bank_db[user_acc]['balance'])
        
        

def create_account():
    pass



print("-" * 5, "Welcome to the ABC Bank", "-" * 5)

while True:
    print("\nMAIN MENU")
    print("1. Login")
    print("2. Create Account")
    print("3. Exit")
    
    main_choice = input("Choose an option: ")

    if main_choice == '1':
        try:
            user_acc = int(input("Enter Account Number: "))
            user_pin = int(input("Enter PIN: "))
            
            if user_acc in bank_db and bank_db[user_acc]['pin'] == user_pin:
                perform_transactions(user_acc)
            else:
                print("Access Denied: Invalid Account Number or PIN.")
        except ValueError:
            print("Error: Please enter numeric values.")

    elif main_choice == '2':
        create_account()

    elif main_choice == '3':
        print("Thank you for banking with us.")
        sys.exit()
    
    else:
        print("Invalid selection.")
# Out:
# ----- Welcome to the ABC Bank -----
#
# MAIN MENU
# 1. Login
# 2. Create Account
# 3. Exit
#
# Choose an option :
# Balance Amount : ₹ 5000
#
# MAIN MENU
# 1. Login
# 2. Create Account
# 3. Exit
#
# Choose an option :
#
# MAIN MENU
# 1. Login
# 2. Create Account
# 3. Exit
#
# Choose an option :
# Balance Amount : ₹ 5500
#
# MAIN MENU
# 1. Login
# 2. Create Account
# 3. Exit
#
# Choose an option :
# Withdrew Amount : ₹ 2000
# Balance : ₹ 3500
#
# MAIN MENU
# 1. Login
# 2. Create Account
# 3. Exit
# Thank you for banking with us.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
